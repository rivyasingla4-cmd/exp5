# %%
#rivya singla
# 25070123091
#exp5
#Creation of dictionary
cardict = { "Brand": "Ford", "Model":"Mustang", "Year": 1964}
print(cardict)
# Out:
# {'Brand': 'Ford', 'Model': 'Mustang', 'Year': 1964}

# %%
cardict = {"Brand": "Ford", "Model":"Mustang", "Year": 1964}
print(cardict["Brand"])
# Out:
# Ford

# %%
# Dictionary takes lastest value given for key. It will not allow duplicates
cardict = {"Brand": "Ford", "Model":"Mustang", "Year": 1964, "Year": 2020}
print(cardict)
# Out:
# {'Brand': 'Ford', 'Model': 'Mustang', 'Year': 2020}

# %%
#Length of key-value pairs
len(cardict)
# Out:
# 3

# %%
cardict = {"Brand": "Ford", "Model":"Mustang", "Year": 1964}
print(type(cardict))
# Out:
# <class 'dict'>

# %%
#Changing/Adding key: Value in dictionary
cardict = {"Brand": "Ford", "Model":"Mustang", "Year": 1964}
cardict.update({"colour": "red"})
print(cardict)

x = cardict.values()
print(x)
# Out:
# {'Brand': 'Ford', 'Model': 'Mustang', 'Year': 1964, 'colour': 'red'}
# dict_values(['Ford', 'Mustang', 1964, 'red'])

# %%
#Retrival of values
student = {"Roll": 98, "Name": "Rivya", "Branch": "ENTC"}
print("Name:", student["Name"])
# Out:
# Name: Rupsa

# %%
#Removing of values
student = {"Roll": 98, "Name": "Rupsa", "Branch": "ENTC"}
student.pop("Branch")
print(student)
# Out:
# {'Roll': 98, 'Name': 'Rupsa'}

# %%
#question1
product = {"Biscuit": 50, "Dairy Milk": 10, "Pen": 30, "Pencil": 2}
print("Products:", product)
product.update({"Pen": 20})
print("Updated Products:" ,product)
# Out:
# Products: {'Biscuit': 50, 'Dairy Milk': 10, 'Pen': 30, 'Pencil': 2}
# Updated Products: {'Biscuit': 50, 'Dairy Milk': 10, 'Pen': 20, 'Pencil': 2}

# %%
#question2
studentmarks = {"Rivya":100, "Rahul": 89, "Ram": 56, "Siya": 92}
Name = input("Enter Student Name:")
print(studentmarks.get(Name, "Student not found"))
# Out:
# Enter Student Name:rivya
# Student not found

# %%
#question3
username_passwords = {"Rivya":"1204", "Ronit":"1908", "Amit":"2504",}
username = input("Enter Username:")
password = input("Enter Password:")
if username_passwords.get(username) == password:
   print("Login Successful")
else:
     print("Invalid username or password")
# Out:
# Enter Username:rivya
# Enter Password:rivya1234
# Invalid username or password

# %%
#question4
studentmarks = {"Rivya":100, "Rahul": 89, "Ram": 56, "Siya": 92}
topper = max(studentmarks, key=studentmarks.get)
print("Topper:", topper)
print("Marks:", studentmarks[topper])
# Out:
# Topper: Rivya
# Marks: 100
